# %% [markdown]
# <a href="https://colab.research.google.com/github/Alonsobarrera27/Probabilidad-/blob/main/unidad2/probabilidad_U2_Programa3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image](https://github.com/JoseGabriel-ITD/Probabilidad-y-Estadistica/blob/main/Cintilla2004.png?raw=true)
#
# ## **Programacion orientada a objetos**
#
#
# **Practica 3**
#
#
# ## **Grupo 2Y**
#
#
# ## **Unidad 2**
#
# ### Docente: Jose Gabriel Rodriguez Rivas
#
# ### Alumno: Jose Alonso Perez Barrera

# %%
import itertools

# Lista de asistentes (pueden ser nombres)
asistentes = [f"A{i}" for i in range(1, 11)]

# Generar todas las combinaciones posibles de 4 asistentes
combinaciones = list(itertools.combinations(asistentes, 4))

# Mostrar cuántas combinaciones hay
print("Número total de combinaciones:", len(combinaciones))

# Mostrar todas las combinaciones
for c in combinaciones:
    print(c)
# Out:
# Número total de combinaciones: 210
# ('A1', 'A2', 'A3', 'A4')
# ('A1', 'A2', 'A3', 'A5')
# ('A1', 'A2', 'A3', 'A6')
# ('A1', 'A2', 'A3', 'A7')
# ('A1', 'A2', 'A3', 'A8')
# ('A1', 'A2', 'A3', 'A9')
# ('A1', 'A2', 'A3', 'A10')
# ('A1', 'A2', 'A4', 'A5')
# ('A1', 'A2', 'A4', 'A6')
# ('A1', 'A2', 'A4', 'A7')
# ('A1', 'A2', 'A4', 'A8')
# ('A1', 'A2', 'A4', 'A9')
# ('A1', 'A2', 'A4', 'A10')
# ('A1', 'A2', 'A5', 'A6')
# ('A1', 'A2', 'A5', 'A7')
# ('A1', 'A2', 'A5', 'A8')
# ('A1', 'A2', 'A5', 'A9')
# ('A1', 'A2', 'A5', 'A10')
# ('A1', 'A2', 'A6', 'A7')
# ('A1', 'A2', 'A6', 'A8')
# ('A1', 'A2', 'A6', 'A9')
# ('A1', 'A2', 'A6', 'A10')
# ('A1', 'A2', 'A7', 'A8')
# ('A1', 'A2', 'A7', 'A9')
# ('A1', 'A2', 'A7', 'A10')
# ('A1', 'A2', 'A8', 'A9')
# ('A1', 'A2', 'A8', 'A10')
# ('A1', 'A2', 'A9', 'A10')
# ('A1', 'A3', 'A4', 'A5')
# ('A1', 'A3', 'A4', 'A6')
# ('A1', 'A3', 'A4', 'A7')
# ('A1', 'A3', 'A4', 'A8')
# ('A1', 'A3', 'A4', 'A9')
# ('A1', 'A3', 'A4', 'A10')
# ('A1', 'A3', 'A5', 'A6')
# ('A1', 'A3', 'A5', 'A7')
# ('A1', 'A3', 'A5', 'A8')
# ('A1', 'A3', 'A5', 'A9')
# ('A1', 'A3', 'A5', 'A10')
# ('A1', 'A3', 'A6', 'A7')
# ('A1', 'A3', 'A6', 'A8')
# ('A1', 'A3', 'A6', 'A9')
# ('A1', 'A3', 'A6', 'A10')
# ('A1', 'A3', 'A7', 'A8')
# ('A1', 'A3', 'A7', 'A9')
# ('A1', 'A3', 'A7', 'A10')
# ('A1', 'A3', 'A8', 'A9')
# ('A1', 'A3', 'A8', 'A10')
# ('A1', 'A3', 'A9', 'A10')
# ('A1', 'A4', 'A5', 'A6')
# ('A1', 'A4', 'A5', 'A7')
# ('A1', 'A4', 'A5', 'A8')
# ('A1', 'A4', 'A5', 'A9')
# ('A1', 'A4', 'A5', 'A10')
# ('A1', 'A4', 'A6', 'A7')
# ('A1', 'A4', 'A6', 'A8')
# ('A1', 'A4', 'A6', 'A9')
# ('A1', 'A4', 'A6', 'A10')
# ('A1', 'A4', 'A7', 'A8')
# ('A1', 'A4', 'A7', 'A9')
# ('A1', 'A4', 'A7', 'A10')
# ('A1', 'A4', 'A8', 'A9')
# ('A1', 'A4', 'A8', 'A10')
# ('A1', 'A4', 'A9', 'A10')
# ('A1', 'A5', 'A6', 'A7')
# ('A1', 'A5', 'A6', 'A8')
# ('A1', 'A5', 'A6', 'A9')
# ('A1', 'A5', 'A6', 'A10')
# ('A1', 'A5', 'A7', 'A8')
# ('A1', 'A5', 'A7', 'A9')
# ('A1', 'A5', 'A7', 'A10')
# ('A1', 'A5', 'A8', 'A9')
# ('A1', 'A5', 'A8', 'A10')
# ('A1', 'A5', 'A9', 'A10')
# ('A1', 'A6', 'A7', 'A8')
# ('A1', 'A6', 'A7', 'A9')
# ('A1', 'A6', 'A7', 'A10')
# ('A1', 'A6', 'A8', 'A9')
# ('A1', 'A6', 'A8', 'A10')
# ('A1', 'A6', 'A9', 'A10')
# ('A1', 'A7', 'A8', 'A9')
# ('A1', 'A7', 'A8', 'A10')
# ('A1', 'A7', 'A9', 'A10')
# ('A1', 'A8', 'A9', 'A10')
# ('A2', 'A3', 'A4', 'A5')
# ('A2', 'A3', 'A4', 'A6')
# ('A2', 'A3', 'A4', 'A7')
# ('A2', 'A3', 'A4', 'A8')
# ('A2', 'A3', 'A4', 'A9')
# ('A2', 'A3', 'A4', 'A10')
# ('A2', 'A3', 'A5', 'A6')
# ('A2', 'A3', 'A5', 'A7')
# ('A2', 'A3', 'A5', 'A8')
# ('A2', 'A3', 'A5', 'A9')
# ('A2', 'A3', 'A5', 'A10')
# ('A2', 'A3', 'A6', 'A7')
# ('A2', 'A3', 'A6', 'A8')
# ('A2', 'A3', 'A6', 'A9')
# ('A2', 'A3', 'A6', 'A10')
# ('A2', 'A3', 'A7', 'A8')
# ('A2', 'A3', 'A7', 'A9')
# ('A2', 'A3', 'A7', 'A10')
# ('A2', 'A3', 'A8', 'A9')
# ('A2', 'A3', 'A8', 'A10')
# ('A2', 'A3', 'A9', 'A10')
# ('A2', 'A4', 'A5', 'A6')
# ('A2', 'A4', 'A5', 'A7')
# ('A2', 'A4', 'A5', 'A8')
# ('A2', 'A4', 'A5', 'A9')
# ('A2', 'A4', 'A5', 'A10')
# ('A2', 'A4', 'A6', 'A7')
# ('A2', 'A4', 'A6', 'A8')
# ('A2', 'A4', 'A6', 'A9')
# ('A2', 'A4', 'A6', 'A10')
# ('A2', 'A4', 'A7', 'A8')
# ('A2', 'A4', 'A7', 'A9')
# ('A2', 'A4', 'A7', 'A10')
# ('A2', 'A4', 'A8', 'A9')
# ('A2', 'A4', 'A8', 'A10')
# ('A2', 'A4', 'A9', 'A10')
# ('A2', 'A5', 'A6', 'A7')
# ('A2', 'A5', 'A6', 'A8')
# ('A2', 'A5', 'A6', 'A9')
# ('A2', 'A5', 'A6', 'A10')
# ('A2', 'A5', 'A7', 'A8')
# ('A2', 'A5', 'A7', 'A9')
# ('A2', 'A5', 'A7', 'A10')
# ('A2', 'A5', 'A8', 'A9')
# ('A2', 'A5', 'A8', 'A10')
# ('A2', 'A5', 'A9', 'A10')
# ('A2', 'A6', 'A7', 'A8')
# ('A2', 'A6', 'A7', 'A9')
# ('A2', 'A6', 'A7', 'A10')
# ('A2', 'A6', 'A8', 'A9')
# ('A2', 'A6', 'A8', 'A10')
# ('A2', 'A6', 'A9', 'A10')
# ('A2', 'A7', 'A8', 'A9')
# ('A2', 'A7', 'A8', 'A10')
# ('A2', 'A7', 'A9', 'A10')
# ('A2', 'A8', 'A9', 'A10')
# ('A3', 'A4', 'A5', 'A6')
# ('A3', 'A4', 'A5', 'A7')
# ('A3', 'A4', 'A5', 'A8')
# ('A3', 'A4', 'A5', 'A9')
# ('A3', 'A4', 'A5', 'A10')
# ('A3', 'A4', 'A6', 'A7')
# ('A3', 'A4', 'A6', 'A8')
# ('A3', 'A4', 'A6', 'A9')
# ('A3', 'A4', 'A6', 'A10')
# ('A3', 'A4', 'A7', 'A8')
# ('A3', 'A4', 'A7', 'A9')
# ('A3', 'A4', 'A7', 'A10')
# ('A3', 'A4', 'A8', 'A9')
# ('A3', 'A4', 'A8', 'A10')
# ('A3', 'A4', 'A9', 'A10')
# ('A3', 'A5', 'A6', 'A7')
# ('A3', 'A5', 'A6', 'A8')
# ('A3', 'A5', 'A6', 'A9')
# ('A3', 'A5', 'A6', 'A10')
# ('A3', 'A5', 'A7', 'A8')
# ('A3', 'A5', 'A7', 'A9')
# ('A3', 'A5', 'A7', 'A10')
# ('A3', 'A5', 'A8', 'A9')
# ('A3', 'A5', 'A8', 'A10')
# ('A3', 'A5', 'A9', 'A10')
# ('A3', 'A6', 'A7', 'A8')
# ('A3', 'A6', 'A7', 'A9')
# ('A3', 'A6', 'A7', 'A10')
# ('A3', 'A6', 'A8', 'A9')
# ('A3', 'A6', 'A8', 'A10')
# ('A3', 'A6', 'A9', 'A10')
# ('A3', 'A7', 'A8', 'A9')
# ('A3', 'A7', 'A8', 'A10')
# ('A3', 'A7', 'A9', 'A10')
# ('A3', 'A8', 'A9', 'A10')
# ('A4', 'A5', 'A6', 'A7')
# ('A4', 'A5', 'A6', 'A8')
# ('A4', 'A5', 'A6', 'A9')
# ('A4', 'A5', 'A6', 'A10')
# ('A4', 'A5', 'A7', 'A8')
# ('A4', 'A5', 'A7', 'A9')
# ('A4', 'A5', 'A7', 'A10')
# ('A4', 'A5', 'A8', 'A9')
# ('A4', 'A5', 'A8', 'A10')
# ('A4', 'A5', 'A9', 'A10')
# ('A4', 'A6', 'A7', 'A8')
# ('A4', 'A6', 'A7', 'A9')
# ('A4', 'A6', 'A7', 'A10')
# ('A4', 'A6', 'A8', 'A9')
# ('A4', 'A6', 'A8', 'A10')
# ('A4', 'A6', 'A9', 'A10')
# ('A4', 'A7', 'A8', 'A9')
# ('A4', 'A7', 'A8', 'A10')
# ('A4', 'A7', 'A9', 'A10')
# ('A4', 'A8', 'A9', 'A10')
# ('A5', 'A6', 'A7', 'A8')
# ('A5', 'A6', 'A7', 'A9')
# ('A5', 'A6', 'A7', 'A10')
# ('A5', 'A6', 'A8', 'A9')
# ('A5', 'A6', 'A8', 'A10')
# ('A5', 'A6', 'A9', 'A10')
# ('A5', 'A7', 'A8', 'A9')
# ('A5', 'A7', 'A8', 'A10')
# ('A5', 'A7', 'A9', 'A10')
# ('A5', 'A8', 'A9', 'A10')
# ('A6', 'A7', 'A8', 'A9')
# ('A6', 'A7', 'A8', 'A10')
# ('A6', 'A7', 'A9', 'A10')
# ('A6', 'A8', 'A9', 'A10')
# ('A7', 'A8', 'A9', 'A10')
