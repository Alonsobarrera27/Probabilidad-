# %% [markdown]
# <a href="https://colab.research.google.com/github/Alonsobarrera27/Probabilidad-/blob/main/Unidad%201/Practica1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Probabilidad y estadistica**
#
# **Practica 1: Medidas de tendencia central e histogramas**
#
# ## Grupo 2 Y
#
# ## **Unidad 1**
#
# ## Docente: Jose Gabriel Rodriguez Rivas
#
# ## Alumno: Jose Alonso Perez Barrera

# %%
from statistics import *

#Lista de calificaciones del grupo a
grupoa=[70,70,65,90,100,95,45,80,73,20,100,96]
print(grupoa)

type(grupoa)

promedio= sum(grupoa)/len(grupoa)
print(promedio)

promedio2=mean(grupoa)
print(promedio2)

mediana=median(grupoa)
print(mediana)

moda=mode(grupoa)
print(moda)

moda2=multimode(grupoa)
print(moda2)

tiempos100mts=[15.10,17.20,14.69,13.27,22.15,18.71,19.15,20.65,15.10,17.20]
print(tiempos100mts)

print("El tiempo promedio de los corredores es=> ", mean (tiempos100mts))

mediana=median(tiempos100mts)
print("La media  de los tiempos de los corredores es=> ", mediana)

moda=mode(tiempos100mts)
print("La moda de los tiempos es=>",moda)

multimoda=multimode(tiempos100mts)
print("La multi moda de los tiempos es=>",multimoda)

import random

fabrica1=[]
for i in range(100):
  numero_aleatorio = round(random.uniform(50, 100), 2 )
  fabrica1.append(numero_aleatorio)
print(fabrica1)

fabrica2=[]
for i in range (100) :
  numero_aleatorio2 = round(random.uniform(40, 93), 2 )
  fabrica2.append(numero_aleatorio2)
print(fabrica2)

import matplotlib.pyplot as plt

import matplotlib.pyplot as plt
plt.hist(fabrica1)
plt.title("Produccion diaria de la fabrica 1")

import matplotlib.pyplot as plt
plt.hist(fabrica2)
plt.title("Produccion diaria de la fabrica 2")

from statistics import *

media1 = mean(fabrica1)
mediana1 = median(fabrica1)
moda1 = mode(fabrica1)

print("Valores de la fabrica 1")
print("La media de la fabrica 1 es=>",media1)
print("La mediana de la fabrica 1 es=>",mediana1)
print("La moda de la fabrica 1 es=>",moda1)

media2 = mean(fabrica2)
mediana2 = median(fabrica2)
moda2 = mode(fabrica2)

print("Valores de la fabrica 2")
print("La media de la fabrica 2 es=>",media2)
print("La mediana de la fabrica 2 es=>",mediana2)
print("La moda de la fabrica 2 es=>",moda2)

fig, (ax1, ax2) = plt.subplots(nrows = 1, ncols = 2, figsize = (10, 5))
ax1. hist(fabrica1)
ax2.hist(fabrica2)
plt. show()

plt.hist(fabrica1, bins=10, alpha=0.2, color='b', edgecolor = "black")
plt.axvline(media1, color='b', linestyle='dashed', linewidth=2, label='Media')
plt.axvline(mediana1, color='r', linestyle='dashed', linewidth=2, label="Mediana")
plt.axvline(moda1, color='y', linestyle='dashed', linewidth=2, label='Moda')
plt.xlabel ('Valor')
plt.ylabel('Frecuencia')
plt.title("Producción diaria de la fabrica 1")
plt.legend()
plt.show()

plt.hist(fabrica2, bins=10, alpha=0.2, color='b', edgecolor = "black")
plt.axvline(media2, color='b', linestyle='dashed', linewidth=2, label='Media')
plt.axvline(mediana2, color='r', linestyle='dashed', linewidth=2, label="Mediana")
plt.axvline(moda2, color='y', linestyle='dashed', linewidth=2, label='Moda')
plt.xlabel ('Valor')
plt.ylabel('Frecuencia')
plt.title("Producción diaria de la fabrica 2")
plt.legend()
plt.show()
# Out:
# [70, 70, 65, 90, 100, 95, 45, 80, 73, 20, 100, 96]
# 75.33333333333333
# 75.33333333333333
# 76.5
# 70
# [70, 100]
# [15.1, 17.2, 14.69, 13.27, 22.15, 18.71, 19.15, 20.65, 15.1, 17.2]
# El tiempo promedio de los corredores es=>  17.322
# La media  de los tiempos de los corredores es=>  17.2
# La moda de los tiempos es=> 15.1
# La multi moda de los tiempos es=> [15.1, 17.2]
# [84.42, 78.24, 56.98, 70.77, 93.4, 91.2, 99.57, 80.36, 94.66, 76.25, 51.53, 83.89, 95.78, 88.65, 83.77, 51.14, 63.71, 71.66, 93.56, 82.29, 73.48, 80.48, 78.05, 72.37, 68.76, 64.34, 94.4, 63.73, 64.24, 97.82, 75.33, 60.76, 89.64, 76.61, 58.28, 50.75, 77.05, 95.43, 96.61, 57.53, 78.84, 60.31, 89.44, 72.51, 80.46, 91.57, 51.63, 87.18, 57.03, 85.15, 92.35, 67.37, 51.46, 88.08, 86.45, 81.33, 66.63, 84.25, 53.69, 83.4, 60.05, 72.65, 81.45, 93.03, 82.48, 89.49, 74.57, 59.13, 90.99, 72.87, 97.88, 65.59, 71.92, 59.9, 50.18, 88.59, 56.45, 96.83, 53.29, 99.52, 75.8, 64.8, 69.09, 50.85, 55.83, 61.92, 54.85, 61.39, 76.15, 80.7, 63.24, 70.0, 91.53, 59.34, 50.39, 95.79, 83.3, 89.86, 73.32, 96.21]
# [83.75, 70.66, 53.74, 61.16, 85.32, 69.49, 43.95, 53.3, 89.67, 61.14, 45.49, 45.12, 69.91, 64.84, 71.2, 58.05, 60.5, 56.12, 55.26, 46.2, 72.4, 89.79, 64.36, 84.46, 69.68, 61.15, 47.74, 54.0, 64.36, 54.67, 61.47, 62.48, 56.09, 51.53, 53.14, 43.71, 81.19, 87.28, 65.75, 40.68, 90.24, 81.79, 85.12, 70.48, 83.36, 60.87, 80.27, 44.34, 43.31, 83.23, 72.69, 59.76, 71.34, 42.99, 48.56, 70.38, 42.7, 47.78, 89.64, 92.95, 62.78, 58.16, 68.37, 60.01, 55.28, 81.79, 69.67, 80.08, 45.7, 48.4, 56.83, 88.29, 64.93, 87.46, 51.18, 79.77, 56.91, 47.33, 56.9, 40.27, 59.01, 89.1, 81.27, 40.26, 82.3, 51.4, 78.21, 57.13, 74.62, 87.42, 69.03, 65.55, 45.91, 50.42, 60.74, 44.3, 42.94, 74.44, 51.4, 72.76]
# Valores de la fabrica 1
# La media de la fabrica 1 es=> 75.3784
# La mediana de la fabrica 1 es=> 76.2
# La moda de la fabrica 1 es=> 84.42
# Valores de la fabrica 2
# La media de la fabrica 2 es=> 64.1092
# La mediana de la fabrica 2 es=> 61.315
# La moda de la fabrica 2 es=> 64.36
